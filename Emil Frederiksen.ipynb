# %%
import pandas as pd

matchstats_df = pd.read_csv(r'C:\Users\Seamus-admin\Documents\GitHub\AC-Horsens-First-Team\DNK_1_Division_2024_2025\matchstats_all DNK_1_Division_2024_2025.csv')

matchstats_df = matchstats_df[matchstats_df['team_name'] == 'OB']

# %%
goals_per_position = matchstats_df.groupby(['player_position']).sum('goals').reset_index()
goals_per_position = goals_per_position[['player_position','goals']]
print(goals_per_position)
# Out:
#         player_position  goals
# 0  Attacking Midfielder    1.0
# 1              Defender    9.0
# 2  Defensive Midfielder    1.0
# 3            Goalkeeper    0.0
# 4            Midfielder    8.0
# 5               Striker   40.0
# 6            Substitute    7.0
